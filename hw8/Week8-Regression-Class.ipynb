# %%
import pandas as pd
import numpy as np
import scipy
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('AutoMPG.csv')

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %%
df = df.drop(['car name'],axis=1)

# %%
X = df.drop(['mpg'],axis=1)
Y = df['mpg']

# %%
model = sm.OLS(Y,sm.add_constant(X['weight'])).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     789.4
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):           9.49e-96
# Time:                        20:07:46   Log-Likelihood:                -1147.2
# No. Observations:                 392   AIC:                             2298.
# Df Residuals:                     390   BIC:                             2306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         45.9223      0.835     55.020      0.000      44.281      47.563
# ...

# %%
plt.plot(df['weight'],df['mpg'],'ro')
plt.plot(df['weight'],model.fittedvalues,  'b')
plt.legend(['Data', 'Fitted model'])
plt.xlabel('weight')
plt.ylabel('mpg')
# Out:
# Text(0, 0.5, 'mpg')

# %%
modelall = sm.OLS(Y,sm.add_constant(X)).fit()

# %%
modelall.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.787
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     202.6
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):          1.02e-124
# Time:                        20:09:14   Log-Likelihood:                -1061.1
# No. Observations:                 392   AIC:                             2138.
# Df Residuals:                     384   BIC:                             2170.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Another Function for Linear Regression

# %%
model2 = ols("mpg ~ weight", data=df).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.669
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     789.4
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):           9.49e-96
# Time:                        19:59:37   Log-Likelihood:                -1147.2
# No. Observations:                 392   AIC:                             2298.
# Df Residuals:                     390   BIC:                             2306.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     45.9223      0.835     55.020      0.000      44.281      47.563
# ...

# %% [markdown]
# ## Seaborn to plot Regression Line

# %%
#Seaborn
sns.lmplot(x='weight', y='mpg', data=df)

# %% [markdown]
# ### One Hot Encoding - for categorical columns

# %%
df = pd.read_csv('AutoMPG.csv')

# %%
df['Type'] = 'Old'

# %%
df.loc[df['model year'] > 70, 'Type'] = 'New'

# %%
df = df.drop('car name',axis=1)

# %%
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin Type
# 0            70       1  Old
# 1            70       1  Old
# 2            70       1  Old
# ...

# %%
X = df.drop(['mpg'],axis=1)
Y = df['mpg']

# %%
modelcat = sm.OLS(Y,sm.add_constant(X)).fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30332/2837015918.py in <module>
# ----> 1 modelcat = sm.OLS(Y,sm.add_constant(X)).fit()
#
# ~\anaconda3\envs\python-r\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     870     def __init__(self, endog, exog=None, missing='none', hasconst=None,
#     871                  **kwargs):
# --> 872         super(OLS, self).__init__(endog, exog, missing=missing,
#     873                                   hasconst=hasconst, **kwargs)
#     874         if "weights" in self._init_keys:
#
# ~\anaconda3\envs\python-r\lib\site-packages\statsmodels\regression\linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     701         else:
#     702             weights = weights.squeeze()
# ...

# %%
one_hot = pd.get_dummies(df, columns = ['Type'])

# %%
one_hot
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 387  27.0          4         140.0          86    2790          15.6
# 388  44.0          4          97.0          52    2130          24.6
# 389  32.0          4         135.0          84    2295          11.6
# 390  28.0          4         120.0          79    2625          18.6
# 391  31.0          4         119.0          82    2720          19.4
#
#      model year  origin  Type_New  Type_Old
# 0            70       1         0         1
# 1            70       1         0         1
# ...

# %%
X = one_hot.drop(['mpg'],axis=1)
Y = one_hot['mpg']

# %%
modelcat = sm.OLS(Y,sm.add_constant(X)).fit()

# %%
modelcat.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    mpg   R-squared:                       0.791
# Model:                            OLS   Adj. R-squared:                  0.787
# Method:                 Least Squares   F-statistic:                     181.1
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):          4.34e-125
# Time:                        20:29:58   Log-Likelihood:                -1057.4
# No. Observations:                 392   AIC:                             2133.
# Df Residuals:                     383   BIC:                             2169.
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...
