# %% [markdown]
# # CS 457 - Homework Assignment 5: SQL
# ## Fahad Ahmed
# ### fs05847@st.habib.edu.pk

# %%
import pyodbc
import pandas as pd
import pandas.io.sql as psql

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=LAPTOP-2S9RV31K\SQLEXPRESS;'
                      'Database=DS_HW5;'
                      'Trusted_Connection=yes;')

cursor = conn.cursor()
# cursor.execute('SELECT TOP(1) * FROM employeeattrition1,')

# %%
df = psql.read_sql('select * from employeeattrition1 e1, employeeattrition2 e2 where e1.EmployeeNumber = e2.EmployeeNumber', conn)

# %%
df.head()
# Out:
#    EmployeeNumber  Age     BusinessTravel  DailyRate              Department  \
# 0               1   41      Travel_Rarely       1102                   Sales
# 1               2   49  Travel_Frequently        279  Research & Development
# 2               4   37      Travel_Rarely       1373  Research & Development
# 3               5   33  Travel_Frequently       1392  Research & Development
# 4               7   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %%
import seaborn as sns                      
import matplotlib.pyplot as plt             
# %matplotlib inline

# %%
a = df['JobRole'].value_counts()
df['JobRole'].value_counts().plot(kind='bar', figsize=(10,4))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### On X-axis we have JobRoles and on Y-axis we have Count
# ### as we can see from the above bar graph the most common type of Job Role is "Sales-Executive", it has the biggest bar above 300. The second and third most common Job Role is "Research Scientist" and "Labortaory Technician", there bar is between 250 to 300. Rest of the Job_Roles are less than 150. There are total 9 different types of Job Roles.

# %%
df['Department'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## X-axis = departments, Y-axis = count
# ## from the above histogram, we can see that company has 3 departments: Sales, Research & Development, Human Resources. The most number of Employees in the company are in "Research & Development" department. Human Resources department has very low employee number, less than 100 as can been in from graph. The Research department has emplyees number closer to 1000 but less 1000. And the Sales department has more than 400 employees in the company

# %%
sns.lmplot(data=df,x="Age", y="MonthlyIncome",line_kws={'color': 'red'},scatter=True)

# %% [markdown]
# ## X-axis = Age, Y-axis = MonthlyIncome
# ### from the above scatter plot we can see that there is a clear positive linear relation between "Age" and 'MonthlyIncome' columns, as the Age of employee increases the MonthlyIncome of the employee also increases.
