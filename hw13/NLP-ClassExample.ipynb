# %%
# from nltk.tokenize import word_tokenize
# from nltk.tag import pos_tag
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
from nltk import pos_tag, word_tokenize, RegexpParser
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
from bs4 import BeautifulSoup
import requests
import re
import numpy
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zeeha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Example text
sample_text = "I shot an elephant in my pajamas"

# %%
# Find all parts of speech in above sentence
tagged = pos_tag(word_tokenize(sample_text))
tagged
# Out:
# [('I', 'PRP'),
#  ('shot', 'VBP'),
#  ('an', 'DT'),
#  ('elephant', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('pajamas', 'NN')]

# %%
#Extract all parts of speech from any text
chunker = RegexpParser("""
                       NP: {<DT>?<JJ>*<NN>}    #To extract Noun Phrases
                       P: {<IN>}               #To extract Prepositions
                       V: {<V.*>}              #To extract Verbs
                       PP: {<P> <NP>}          #To extract Prepostional Phrases
                       VP: {<V> <NP|PP>*}      #To extarct Verb Phrases
                       """)

# %%
# Print all parts of speech in above sentence
output = chunker.parse(tagged)

# %%
# To draw the parse tree
output.draw()

# %%
sent = 'European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices'

# %%
sent_pos = nltk.word_tokenize(sent)
sent_pos = nltk.pos_tag(sent_pos)

# %%
sent_pos
# Out:
# [('European', 'JJ'),
#  ('authorities', 'NNS'),
#  ('fined', 'VBD'),
#  ('Google', 'NNP'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('$', '$'),
#  ('5.1', 'CD'),
#  ('billion', 'CD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('for', 'IN'),
#  ('abusing', 'VBG'),
#  ('its', 'PRP$'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mobile', 'JJ'),
#  ('phone', 'NN'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('alter', 'VB'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS')]

# %% [markdown]
# ### See all the pos tag list here
# ### https://www.guru99.com/pos-tagging-chunking-nltk.html

# %% [markdown]
# ## SpaCy Library NER

# %%
#SpaCy’s named entity recognition has been trained on the OntoNotes 5 corpus and it supports the following entity types:

# %%
# CARDINAL, DATE, EVENT, FAC, GPE, LANGUAGE, LAW, LOC, MONEY, NORP, ORDINAL, ORG, PERCENT, PERSON, PRODUCT, QUANTITY, TIME, WORK_OF_ART

# %%
# nlp = en_core_web_sm.load()
nlp = spacy.load('en_core_web_sm')
doc = nlp('European authorities fined Google a record $5.1 billion on Wednesday for abusing its power in the mobile phone market and ordered the company to alter its practices')
print([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'), ('Google', 'ORG'), ('$5.1 billion', 'MONEY'), ('Wednesday', 'DATE')]

# %%
# IOB SCHEME
# I – Token is inside an entity.
# O – Token is outside an entity.
# B – Token is the beginning of an entity.

# %%
print([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'), (authorities, 'O', ''), (fined, 'O', ''), (Google, 'B', 'ORG'), (a, 'O', ''), (record, 'O', ''), ($, 'B', 'MONEY'), (5.1, 'I', 'MONEY'), (billion, 'I', 'MONEY'), (on, 'O', ''), (Wednesday, 'B', 'DATE'), (for, 'O', ''), (abusing, 'O', ''), (its, 'O', ''), (power, 'O', ''), (in, 'O', ''), (the, 'O', ''), (mobile, 'O', ''), (phone, 'O', ''), (market, 'O', ''), (and, 'O', ''), (ordered, 'O', ''), (the, 'O', ''), (company, 'O', ''), (to, 'O', ''), (alter, 'O', ''), (its, 'O', ''), (practices, 'O', '')]

# %%
def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    for script in soup(["script", "style", 'aside']):
        script.extract()
        return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
ny_bb = url_to_string('https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-columnregion&region=top-news&WT.nav=top-news')
article = nlp(ny_bb)
len(article.ents)
# Out:
# 162

# %%
labels = [x.label_ for x in article.ents]
Counter(labels)
# Out:
# Counter({'PERSON': 81,
#          'GPE': 13,
#          'ORG': 33,
#          'CARDINAL': 6,
#          'DATE': 20,
#          'PRODUCT': 3,
#          'NORP': 3,
#          'ORDINAL': 1,
#          'EVENT': 1,
#          'FAC': 1})

# %%
items = [x.text for x in article.ents]
Counter(items).most_common(3)
# Out:
# [('Strzok', 32), ('F.B.I.', 17), ('Trump', 13)]

# %%
sentences = [x for x in article.sents]
print(sentences[10])
# Out:
# Mr. Trump’s victory traces back to June, when Mr. Strzok’s conduct was laid out in a wide-ranging inspector general’s report on how the F.B.I. handled the investigation of Hillary Clinton’s emails in the run-up to the 2016 election.

# %%
displacy.render(nlp(str(sentences[10])), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s victory traces back to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s conduct was laid out in a wide-ranging inspector general’s report on how the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  handled the investigation of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  emails in the run-up to the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  election.</div></span>

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[10])).ents])
# Out:
# {'Trump': 'PERSON',
#  'June': 'DATE',
#  'Strzok': 'PERSON',
#  'F.B.I.': 'ORG',
#  'Hillary Clinton’s': 'PERSON',
#  '2016': 'DATE'}

# %% [markdown]
# #### Lemmatization

# %%
[(x.orth_,x.pos_, x.lemma_) for x in [y for y in nlp(str(sentences[10])) if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Mr.', 'PROPN', 'Mr.'),
#  ('Trump', 'PROPN', 'Trump'),
#  ('victory', 'NOUN', 'victory'),
#  ('traces', 'VERB', 'trace'),
#  ('June', 'PROPN', 'June'),
#  ('Mr.', 'PROPN', 'Mr.'),
#  ('Strzok', 'PROPN', 'Strzok'),
#  ('conduct', 'NOUN', 'conduct'),
#  ('laid', 'VERB', 'lay'),
#  ('wide', 'ADV', 'wide'),
#  ('ranging', 'VERB', 'range'),
#  ('inspector', 'NOUN', 'inspector'),
#  ('general', 'NOUN', 'general'),
#  ('report', 'NOUN', 'report'),
#  ('F.B.I.', 'PROPN', 'F.B.I.'),
#  ('handled', 'VERB', 'handle'),
#  ('investigation', 'NOUN', 'investigation'),
#  ('Hillary', 'PROPN', 'Hillary'),
#  ('Clinton', 'PROPN', 'Clinton'),
#  ('emails', 'NOUN', 'email'),
#  ('run', 'NOUN', 'run'),
#  ('2016', 'NUM', '2016'),
#  ('election', 'NOUN', 'election')]

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">[ F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is Fired -
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#     SectionsSEARCHSkip to contentSkip to site indexPoliticsLog inToday’s PaperPolitics|F.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is Firedhttps://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.htmlGive this article1626AdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  reading the main storyF.B.I. Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , Is
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     FiredSend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  any friend a storyAs a subscriber, you have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  gift articles to give
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     each month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ., Anyone can read what you share., Give this article1626Read in
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     appPeter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired.,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Credit...
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T.J. Kirkpatrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TimesBy
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Goldman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael S. SchmidtAug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior counterintelligence agent who disparaged President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin:

# %% [markdown]
# ### PDF Parser - You can use any pdf reader library

# %%
from tika import parser # pip install tika

raw = parser.from_file('1708.05148.pdf')
# print(raw['content'])

# %% [markdown]
# ### Text Summarization

# %%
tokenize_words = nltk.tokenize.word_tokenize(raw['content'])
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(["T", "J", "D", "S", "M", "H", "et al", "et", "pp", "a.", "m.", "d.", "j.", "s.", "r.", "c.", "t."])
no_stopwords = [word for word in tokenize_words if word.lower() not in stopwords]

# remove punctuation, count raw words
nonPunct = re.compile('.*[A-Za-z].*')
clean_words = [w for w in no_stopwords if nonPunct.match(w)]
    
filtered_word_freq = nltk.FreqDist(clean_words)

# %%
filtered_word_freq.most_common(20)
# Out:
# [('language', 66),
#  ('Language', 54),
#  ('text', 51),
#  ('information', 44),
#  ('Natural', 41),
#  ('NLP', 38),
#  ('data', 37),
#  ('words', 31),
#  ('Processing', 30),
#  ('processing', 30),
#  ('Proceedings', 29),
#  ('used', 28),
#  ('using', 26),
#  ('model', 26),
#  ('natural', 24),
#  ('word', 24),
#  ('Medical', 24),
#  ('system', 23),
#  ('systems', 23),
#  ('Association', 23)]

# %%
filtered_word_freq.plot(30,title='Frequency distribution for 30 most common tokens in our text collection (excluding stopwords and punctuation)')
# Out:
# <AxesSubplot:title={'center':'Frequency distribution for 30 most common tokens in our text collection (excluding stopwords and punctuation)'}, xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12, 8]

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(raw['content'])
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["T", "J", "D", "S", "M", "H", "et al", "et", "al"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white").generate(raw['content'])

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ### RAKE Library for Text Summarization (Topic Modeling)

# %%
from rake_nltk import Rake
r = Rake()
r.extract_keywords_from_text(raw['content'])
r.get_ranked_phrases_with_scores()[:10]
# Out:
# [(78.88505776947558,
#   'rennie ., 2000 )[ 46 ][ 47 ][ 48 ], memory based learning'),
#  (65.21934709126491,
#   'androutsopoulos et al ., 2000b )[ 47 ], support vector machines'),
#  (61.88601375793157, 'druker et al ., 1999 )[ 49 ], decision trees'),
#  (60.96969696969697, '79 ][ 80 ][ 81 ][ 82 ][ 83 ].'),
#  (60.96969696969697, '74 ][ 75 ][ 76 ][ 77 ][ 78 ].'),
#  (52.08839471031252, 'pradipta ranjan ray et al ., 2003 )[ 28'),
#  (44.27348484848485,
#   'gdpr (" general data protection regulation ") compliance'),
#  (43.43030303030303,
#   'wide ranging covering usual items like word segmentation'),
#  (42.72380952380952, 'informatique et gestion des unités de soins'),
#  (41.0257053291536, 'powerful general purpose sentence processors like sri ’')]

# %% [markdown]
# ### SpaCy Library for Text Summarization (Topic Modeling)

# %%
nlp = spacy.load('en_core_web_sm')
doc2 = nlp(raw['content'])
print(doc2.ents)
# Out:
# (Aditya Koli, Kiran Khatter, 1,2, Sukhdev Singh, 1,2, Department of Computer Science and Engineering
#
# Manav Rachna International University, Faridabad-121004, India, 2, Accendere Knowledge Management Services Pvt., India
#
#
#
# , NLP, four, NLP, Natural Language Generation, NLP, NLP, NLP, Artificial Intelligence and Linguistics, NLP, two, Natural
#
# Language Understanding, Natural Language Generation, 1, 1, Broad Classification, Linguistics, Syntax, Semantics, Noah Chomsky, one, first, twelfth century, Chomsky, 1965, two, Lower Level, NLP, Automatic Summarization, Machine Translation, Speech Tagging, Machine, one, NLP, Natural Language Processing, one, NLP, Rospocher, 2, English, Dutch, Italian, Natural
#
# Language Processing, NLP, NLP, Natural Language Processing, One, NLP, Natural Language Processing, 3, Shemtov 1997, Emele &, 1998, Knight & Langkilde 2000, 3][4][5, NLP, NLP, Content Planning, 2, 2, NLP, Natural Language Processing
#
# , 1, Linguistics, Ancient Greek, 1993, Nikolai Trubetzkoy, 1998, 6, 2, three, Smallest, 3, NLP, Sundry, first, more than one, one, NLP, 4, NLP, two, 5, Elizabeth D. Liddy,2001, one, 8, 6, NLP, Elizabeth D. Liddy,2001, two, Anaphora Resolution - Anaphora, 7, two, Elizabeth D. Liddy,2001, 3, Natural
#
# Language Processing, four, 3, 3, Levels of Representation, Linguistic Resources, NLP, late 1940s, Russian, English, MT, Chinese, 1967, 10, NLP, 1966, MT, MT, Hutchins, 1986, 11, 1960, AI, 1961, 12, 1978, 13, Winograd SHRDLU, two, ARPA Speech Understanding Research, Lea, 1980, Hendrix, 1978, 14, early 1980s, the end of the decade, SRI’s, 15, 16, e.g, 1987, 17, D)ARPA, 1990s, Young, Chase, 1998, Sundheim, Chinchor, 1993, 18][19, Kobsa, Wahlster, 1989, 20, Cohen, 1990, 21, 1985, 22, NLP, 1988, 23, NLP, 90s, 24, Mani, 1999, 25, 5, NLP, NLP, today, Sentiment Analyser, Chunking, Semantic Role Labelling, NLP, 26, two, European, Arabic, Sanskrit, Namrata Tapswi, 2012, 27, 2003, 28, European, Asian, Arabic, Support Vector Machine, SVM, Mona Diab, 29, Arabic, Noun Phrase, Verb Phrase, NP, Begin Chunk, Inside Chunk, Chunking, Chunking, 2003, 2005, 30, 32, around 94.3%, English, Alan Ritter, 2011, 33, Emotion Detection, 2016, 34, two, English, six, Hindi, English, SRL, PropBank, 2005, 35, SRL, SRL, Edward Benson, al, 36, 6, Machine Translation, Email Spam, Information Extraction, 6.1, Machine Translation, Google Translate, two, Language A, Language B., Google, September 2016, Deep, recent years, Tillmann, 1997, 37, 2000, 38, Nießen, 2000, 39, BLEU, Papineni, 2002, 40, NIST, 2002, 41, 2001, Doddington, 2002, The Carnegie Group’s, Hayes PJ, Westein, 1991)[44, Reuters, first, NLP, Blacklist, Require, Anti-Spam Filtering, 1996)[45, 1998, Androutsopoulos, Rennie, Marquez, 2001)[50, Berger, 2001, 52, 1998, 53, two, 1998, 54, first, first, Bernoulli, second, Bernoulli, Bernoulli, 47, Markov, two, 1998, 55, first, first, Bernoulli, second, Bernoulli, Discovery, the recent years, Chunking, Shadow Parsing, Stop-words (Keywords that
#
# , two, 1980, 55, IR, Reuters, Hayes, 1992, 57, 58, the Blank Slate Language Processor, 1999, 59, MITA, Metlife’s, Glasgow, 1998, 1998, 61, 6.5, two, 62, Fattah, 63, two, 2001, 64, 2007, 65, Wan
#
# 2008, 66, Ouyang, 2011, 67, Mani, 1999, 68, Fattah, 63, Riedhammer, 2010, 69, Topic Model (BSTM, Wang, 2009, 70, FGB, Wang, 2011, 71, 2015, 72, 6.6, Elizabeth D. Liddy, 2001, Windows Cortana, Apple’s Siri, Amazon’s, Alexa, NLP, The Linguistic String Project-Medical Language
#
# Processor, NLP, 74, The National Library of
#
# Medicine, Medline
#
#
#
# , MeSH (Medical Subject Headings, Dorland’s
#
# Illustrated Medical Dictionary, English Dictionaries, The Centre d’Informatique, the Hopital Cantonal de Geneve, NLP, first, French, NLP, Columbia, New
#
# York, NLP, MEDLEE, 97, 7, Noam Chomsky, 98, 99, 100, Logistic, Bayes, 7.1, Hidden Markov Model, HMM, HMM, Inference A, one, Frederick Jelinek, NLP, first, IBM, Speech Recognition Group, 101, HMM, 102, Markov, HMM, HMM, 103, Bayes Classifiers, Bayesian, 8, NLP, NLP, 8.1, Artificial Intelligence, Search, Knowledge
#
# , Applied Cognitive Engine, General Data Protection
#
# Regulation, Robot, AI, GDPR, GDPR Robot, Peter Wallqvist, CSO, EU, 8.2, Capital One, 105, First, U.S., Ken
#
# Computer Application in Medical Care, 235, American Medical Informatics Association, 84, A. T., & Razi, 1994, The UMLS Knowledge Source, 8, 144, 85, J. R., Revillard, 33(2, 174-179, 86, R. H., & Scherrer, J. R., 1992, 31(2, 117, 87, E. C., L. J., N. T., & Scherrer, 1989, November, Proceedings, 553, American Medical Informatics Association, 88, N. T., N., Lyman, L. J., 1989, November, Proceedings, 554, American Medical
#
# Informatics Association, N., Lyman, L. J., N. T., Revillard, & Scherrer, R., 1989, English, French, 89, 799, 90, Nhàn, N. T., Y., Lyman, L. J., & Scherrer, J. R., 1989, Degoulet P, Stephan JC, Yvon PJ, Santé, Colloque AIM-IF, Paris, 91, R. H., & Scherrer, J. R., 1991, AIME 91, 173, Berlin Heidelberg, 92, R. H., Alpay, 12, 103, 93, Baud, R. H., J. R., 1992, 92, 1368-1374, 94, A. M., Baud, R. H., J. R., 1990, Proximity Processing of
#
# Medical Text, Medical Informatics, 625, Berlin Heidelberg, 95, Michel, P. A., Juge, C., Baud, R., J. R., 1994, HELIOS, 45, 96, P. A., Baud, R. H., Lemaitre, D., Jean, F. C., J. R., June, Europe, 42-52, Berlin Heidelberg, 97, Friedman, Cimino, J. J., S. B., 1993, Proceedings, the Annual Symposium on Computer Application in
#
# Medical Care, 829, American Medical Informatics Association, 98, Natural Language Processing, Natural Language Processing RSS, n.d, 23, 2017, Srihari S. Machine Learning:, 2010, 31 May
#
# 2011, http://cseweb, 28 Jun 2011, 62, Hearst MA, Dumais ST, Jurafsky D, Martin JH, 2nd, Englewood Cliffs, Prentice-Hall, 2008, 102, Eddy SR, Birney E, HMM, Nucleic Acids Res, 103, E. L., Eddy, S. R., Birney, R., 1998, HMM, 26(1, 320, PR Newswire, n.d, 19, 2017, 105, SmartData Collective, n.d, 19, 2017, 106, Using Natural Language Processing and Network Analysis to Develop a Conceptual
#
# Framework for Medication Therapy Management Research, U.S. National Library of Medicine, 19, 2017, A. S., 2017, February 10, April 10, 2017, 108, 2016, May 25, April 10, 2017)

# %% [markdown]
# ### Yake Library for Text Summarization (Topic Modeling)

# %%
## conda install -c conda-forge yake
import yake

# %%
kw_extractor = yake.KeywordExtractor()
language = "en"
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
keywords = custom_kw_extractor.extract_keywords(raw['content'])
for kw in keywords:
    print(kw)
# Out:
# ('Natural Language Processing', 4.072522048481498e-05)
# ('Natural Language', 0.00017630910501789887)
# ('Language Processing', 0.0002772259012794197)
# ('Language', 0.0007182928677526841)
# ('Natural Language Generation', 0.0009267846454540823)
# ('Medical language processing', 0.0011647762261847519)
# ('NLP Natural Language', 0.001337310655145573)
# ('Natural', 0.001946179856619044)
# ('Medical Informatics Association', 0.0021316055807476812)
# ('Computational Linguistics', 0.0022099659030024995)
# ('Natural Language Understanding', 0.002233998933477433)
# ('Processing', 0.0022969736217534134)
# ('language processing techniques', 0.0023694804789331256)
# ('Natural language information', 0.002410833598791504)
# ('language information processing', 0.0026347016804727564)
# ('human language', 0.0027613201712648403)
# ('NLP', 0.0030647533731460543)
# ('language processing tools', 0.003157583088635903)
# ('MEDical Language', 0.003266335063269876)
# ('text', 0.003319539662316616)

# %% [markdown]
# # Sentiment Analysis

# %% [markdown]
# # Twitter Data

# %% [markdown]
# ### Sign Up for developer account
# #### https://developer.twitter.com/en/docs/twitter-api/getting-started/getting-access-to-the-twitter-api

# %%
import tweepy as tw
import json
import pandas as pd
import numpy as np
from textblob import TextBlob

# %%
s = TextBlob('CS 457 is the best course throughout my course work')
s.sentiment
# Out:
# Sentiment(polarity=1.0, subjectivity=0.3)

# %%
s = TextBlob('CS 457 is an okay course')
s.sentiment
# Out:
# Sentiment(polarity=0.5, subjectivity=0.5)

# %%
s = TextBlob('CS 457 is the worst course I have ever taken')
s.sentiment
# Out:
# Sentiment(polarity=-1.0, subjectivity=1.0)

# %%
#Part-1: Authorization and Search tweets
#Getting authorization
consumer_key = ''
consumer_key_secret = ''
access_token = ''
access_token_secret = ''
auth = tw.OAuthHandler(consumer_key, consumer_key_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Create a custom search term and define the number of tweets
search_term = "#imrankhan -filter:retweets"

tweets = tw.Cursor(api.search,
                   q=search_term,
                   lang="en",
                   since='2022-04-06').items(100)

# %%
searched_tweets = [t for t in tweets]

# %%
#Part-3: Creating Dataframe of Tweets

#Cleaning searched tweets and converting into Dataframe
my_list_of_dicts = []
for each_json_tweet in searched_tweets:
    my_list_of_dicts.append(each_json_tweet._json)
    
with open('tweet_json_IK_Data.txt', 'w') as file:
        file.write(json.dumps(my_list_of_dicts, indent=4))
        
my_demo_list = []
with open('tweet_json_IK_Data.txt', encoding='utf-8') as json_file:  
    all_data = json.load(json_file)
    for each_dictionary in all_data:
        tweet_id = each_dictionary['id']
        text = each_dictionary['text']
        favorite_count = each_dictionary['favorite_count']
        retweet_count = each_dictionary['retweet_count']
        created_at = each_dictionary['created_at']
        my_demo_list.append({'tweet_id': str(tweet_id),
                             'text': str(text),
                             'favorite_count': int(favorite_count),
                             'retweet_count': int(retweet_count),
                             'created_at': created_at,
                            })
        
        tweet_dataset = pd.DataFrame(my_demo_list, columns = 
                                  ['tweet_id', 'text', 
                                   'favorite_count', 'retweet_count', 
                                   'created_at'])
    
#Writing tweet dataset ti csv file for future reference
tweet_dataset.to_csv('tweet_data_IK.csv',index=False)

# %%
def remove_url(txt):
    #Replace URLs found in a text string with nothing
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
#Removing @ handle
def remove_pattern(input_txt, pattern):
    r = re.findall(pattern, input_txt)
    for i in r:
        input_txt = re.sub(i, '', input_txt)
        
    return input_txt

# %%
tweet_dataset['text'] = np.vectorize(remove_url)(tweet_dataset['text'])

# %%
tweet_dataset['text'] = np.vectorize(remove_pattern)(tweet_dataset['text'], "@[\w]*")

# %%
#Writing tweet dataset ti csv file for future reference
tweet_dataset.to_csv('tweet_data_clean_IK.csv',index=False)

# %%
tweet_dataset = pd.read_csv('tweet_data_clean_IK.csv')

# %%
def tweet_sentiment(txt):
    analysis = TextBlob(txt)
    if analysis.sentiment[0]>=0:
       res = 'positive'
    else:
       res= 'negative'
    return(res)

# %%
tweet_dataset['sentiment'] = np.vectorize(tweet_sentiment)(tweet_dataset['text'])

# %%
tweet_dataset.head(20)
# Out:
#                tweet_id                                               text  \
# 0   1511903264475918336  Pakistans apex court will resume hearing today...
# 1   1511902714472636416  UTURN imrankhan PTI PAKARMY PakistanZindabad I...
# 2   1511901761266761734  Remind me who selected ImranKhanPTI What a sha...
# 3   1511900961127612416  Putin backing of ImranKhan was just a loser jo...
# 4   1511900308653461508  Price of independent ForeignPolicy for a sover...
# 5   1511899721035444224  jomalhotra to chaudhari Gov allegation ag Oppn...
# 6   1511899017004920833  NoConfidenceMotion against ImrankhanPTI govt w...
# 7   1511898617853972488  So they couldnt find anything against ImranKha...
# 8   1511896989327400960  Im having bad feelings about todays Supreme Co...
# 9   1511896772603432969  Happy Birthday Jhalam Ky Shehzady Or ImranKhan...
# 10  1511896543011520512  imrankhan wanting independent foreign policy f...
# 11  1511896293895020547  ImranKhan insisted said conspiracy letter can ...
# 12  1511895732537933826  Russias military intervention in Ukraine is cr...
# 13  1511894109283356683  Two corrupt parties switched power amongst eac...
# 14  1511893874670972929  MintNewsLetter Pakistan is experiencing yet an...
# 15  1511891802802081792  iihtishamm ImranKhans surprise has made them l...
# 16  1511891601957736454  FauziaKasuri Matiullahjan919 Sadly enemy Imran...
# 17  1511890755052204033  Pakistans national assembly speaker AsadQaiser...
# 18  1511889903960870914  Russia has accused the US of another attempt o...
# 19  1511888379457114112  Happy birthday the real janbaz of murshad Imra...
#
#     favorite_count  retweet_count                      created_at sentiment
# 0                0              0  Thu Apr 07 03:06:42 +0000 2022  positive
# 1                0              0  Thu Apr 07 03:04:31 +0000 2022  positive
# 2                1              2  Thu Apr 07 03:00:44 +0000 2022  positive
# 3                0              0  Thu Apr 07 02:57:33 +0000 2022  positive
# 4                0              0  Thu Apr 07 02:54:57 +0000 2022  negative
# 5                0              0  Thu Apr 07 02:52:37 +0000 2022  negative
# 6                0              0  Thu Apr 07 02:49:50 +0000 2022  negative
# 7                0              0  Thu Apr 07 02:48:14 +0000 2022  positive
# 8                0              0  Thu Apr 07 02:41:46 +0000 2022  negative
# 9                1              0  Thu Apr 07 02:40:54 +0000 2022  positive
# 10               0              0  Thu Apr 07 02:40:00 +0000 2022  positive
# 11               0              0  Thu Apr 07 02:39:00 +0000 2022  positive
# 12               1              0  Thu Apr 07 02:36:46 +0000 2022  negative
# 13               0              0  Thu Apr 07 02:30:19 +0000 2022  negative
# 14               3              1  Thu Apr 07 02:29:24 +0000 2022  positive
# 15               2              0  Thu Apr 07 02:21:10 +0000 2022  positive
# 16               0              0  Thu Apr 07 02:20:22 +0000 2022  negative
# 17               5              0  Thu Apr 07 02:17:00 +0000 2022  positive
# 18               0              0  Thu Apr 07 02:13:37 +0000 2022  positive
# 19               0              0  Thu Apr 07 02:07:33 +0000 2022  positive

# %%
corpus = ' '.join(tweet_dataset.text)
# Create stopword list:
stopwords = set(STOPWORDS)
# stopwords.update(["T", "J", "D", "S", "M", "H", "et al"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, max_font_size=50, max_words=100, background_color="white").generate(corpus)

# Display the generated image:
# the matplotlib way:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
